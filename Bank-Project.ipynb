# %% [markdown]
# # Importing Necessary Libiraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Analysing the dataset

# %%
df=pd.read_csv('Bank1.csv')

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
#Calculating no of rows and columns in the dataset
df.shape
# Out:
# (45211, 17)

# %%
#Knowing the math behing the numerical varibles
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
#Information on the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
#Calulating null values in the dataset

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
#From the above dataset we can observe there are no null values present in the dataset

# %%
#Grouping and caluclating the dataset based on the age attribute
l1=[]
l2=[]
f=df.groupby(['age','y']).groups
for i in f:
    l1.append(i[0])
    l1.append(i[1])
    l1.append(len(f[i]))
    l2.append(l1)
    l1=[]
l2
# Out:
# [[18, 'no', 5],
#  [18, 'yes', 7],
#  [19, 'no', 24],
#  [19, 'yes', 11],
#  [20, 'no', 35],
#  [20, 'yes', 15],
#  [21, 'no', 57],
#  [21, 'yes', 22],
#  [22, 'no', 89],
#  [22, 'yes', 40],
#  [23, 'no', 158],
#  [23, 'yes', 44],
#  [24, 'no', 234],
#  [24, 'yes', 68],
#  [25, 'no', 414],
#  [25, 'yes', 113],
#  [26, 'no', 671],
#  [26, 'yes', 134],
#  [27, 'no', 768],
#  [27, 'yes', 141],
#  [28, 'no', 876],
#  [28, 'yes', 162],
#  [29, 'no', 1014],
#  [29, 'yes', 171],
#  [30, 'no', 1540],
#  [30, 'yes', 217],
#  [31, 'no', 1790],
#  [31, 'yes', 206],
#  [32, 'no', 1864],
#  [32, 'yes', 221],
#  [33, 'no', 1762],
#  [33, 'yes', 210],
#  [34, 'no', 1732],
#  [34, 'yes', 198],
#  [35, 'no', 1685],
#  [35, 'yes', 209],
#  [36, 'no', 1611],
#  [36, 'yes', 195],
#  [37, 'no', 1526],
#  [37, 'yes', 170],
#  [38, 'no', 1322],
#  [38, 'yes', 144],
#  [39, 'no', 1344],
#  [39, 'yes', 143],
#  [40, 'no', 1239],
#  [40, 'yes', 116],
#  [41, 'no', 1171],
#  [41, 'yes', 120],
# ...

# %%
df.groupby('y').count()
# Out:
#        age    job  marital  education  default  balance  housing   loan  \
# y
# no   39922  39922    39922      39922    39922    39922    39922  39922
# yes   5289   5289     5289       5289     5289     5289     5289   5289
#
#      contact    day  month  duration  campaign  pdays  previous  poutcome
# y
# no     39922  39922  39922     39922     39922  39922     39922     39922
# yes     5289   5289   5289      5289      5289   5289      5289      5289

# %% [markdown]
# # EDA Analysis

# %%
#Visuvalizing the yes and no from the target varible 'y'

# %%
m=list(df['y'].value_counts())
l11=['No','Yes']
l12=[m[0],m[1]]
colors = sns.color_palette('bright')
plt.pie(l12, labels=l11,colors = colors, autopct = '%0.0f%%')
plt.show()

# %%
df.corr()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.097783 -0.009120 -0.004648  0.004760 -0.023758  0.001288
# balance   0.097783  1.000000  0.004503  0.021560 -0.014578  0.003435  0.016674
# day      -0.009120  0.004503  1.000000 -0.030206  0.162490 -0.093044 -0.051710
# duration -0.004648  0.021560 -0.030206  1.000000 -0.084570 -0.001565  0.001203
# campaign  0.004760 -0.014578  0.162490 -0.084570  1.000000 -0.088628 -0.032855
# pdays    -0.023758  0.003435 -0.093044 -0.001565 -0.088628  1.000000  0.454820
# previous  0.001288  0.016674 -0.051710  0.001203 -0.032855  0.454820  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#From The correlated graph we can observe that duration and day has low correlation so we can drop the columns
df1=df.drop(['day','duration'],axis=1)
df1.shape
# Out:
# (45211, 15)

# %%
df1.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    0        0          0        0     2143        1     0        0
# 1   44    1        1          1        0       29        1     0        0
# 2   33    2        0          1        0        2        1     1        0
# 3   47    3        0          2        0     1506        1     0        0
# 4   33    4        1          2        0        1        0     0        0
#
#    month  campaign  pdays  previous  poutcome  y
# 0      4         1     -1         0         0  0
# 1      4         1     -1         0         0  0
# 2      4         1     -1         0         0  0
# 3      4         1     -1         0         0  0
# 4      4         1     -1         0         0  0

# %%
#Plotting the graph between age and target
plt.figure(figsize=(12,6),dpi=100)
sns.histplot(data=df1,x='age',hue='y',bins=30)
plt.title("AGE VS TARGET")
plt.show()

# %%
#Detecting outliers for the numerical dataset

# %%
def Outlier_detection_numerical(cols):
    d=dict()
    for i in cols:
        Q1=df[i].quantile(q = 0.25)
        Q2=df[i].quantile(q = 0.50)
        Q3=df[i].quantile(q = 0.75)
        Q4=df[i].quantile(q = 1.00)
        IQR=Q3-Q1
        l=Q1-1.5*IQR
        u=Q3+1.5*IQR
        d[i]=u
    return d
Outlier_detection_numerical(df1.select_dtypes(exclude='O').columns)
# Out:
# {'age': 70.5,
#  'balance': 3462.0,
#  'campaign': 6.0,
#  'pdays': -1.0,
#  'previous': 0.0}

# %%
#Conversion of categorical values into numerical using the concept of map

# %%
df1['job']=df1['job'].map({'management':0,'technician':1,'entrepreneur':2,'blue-collar':3,'unknown':4,'retired':5,'admin.':6,
                               'services':7,'self-employed':8,'unemployed':9,'housemaid':10,'student':11})
df1['marital']=df1['marital'].map({'married':0,'single':1,'divorced':2})
df1['education']=df1['education'].map({'tertiary':0,'secondary':1,'unknown':2,'primary':3})
df1['default']=df1['default'].map({'no':0,'yes':1})
df1['housing']=df1['housing'].map({'no':0,'yes':1})
df1['loan']=df1['loan'].map({'no':0,'yes':1})

df1['contact']=df1['contact'].map({'unknown':0,'cellular':1,'telephone':2})
df1['month']=df1['month'].map({'jan':0,'feb':1,'mar':2,'apr':3,'may':4,'jun':5,'jul':6,'aug':7,
                                   'sep':8,'oct':9,'nov':10,'dec':11})
df1['poutcome']=df1['poutcome'].map({'unknown':0,'failure':1,'other':2,'success':3})
df1['y']=df1['y'].map({'no':0,'yes':1})

# %%
df1.tail(30)
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 45181   46    3        0          1        0     6879        0     0        1
# 45182   34    1        0          1        0      133        0     0        1
# 45183   70    5        0          3        0      324        0     0        1
# 45184   63    5        0          1        0     1495        0     0        1
# 45185   60    7        0          0        0     4256        1     0        1
# 45186   59    4        0          2        0     1500        0     0        1
# 45187   32    7        1          1        0     1168        1     0        1
# 45188   29    0        1          1        0      703        1     0        1
# 45189   25    7        1          1        0      199        0     0        1
# 45190   32    3        0          1        0      136        0     0        1
# 45191   75    5        2          0        0     3810        1     0        1
# ...

# %%
plt.figure(figsize=(12,6),dpi=100)
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#Analysis on target varibel

# %%
sns.countplot(x=df1["y"])
plt.show()

# %%
#Analysis on Non target varible using countplot

# %%
l1=list(df1.columns)
l1.pop(-1)
l1
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome']

# %%
for i in l1:
    plt.figure(figsize=(20,5))
    sns.countplot(x=df[i])
    plt.show()

# %% [markdown]
# # Traing the Model

# %%
#Removing target varibel from the dataset to make prediction
df1.shape
# Out:
# (45211, 15)

# %%
non_target=df1.drop('y',axis=1)
non_target.tail(5)
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 45206   51    1        0          0        0      825        0     0        1
# 45207   71    5        2          3        0     1729        0     0        1
# 45208   72    5        0          1        0     5715        0     0        1
# 45209   57    3        0          1        0      668        0     0        2
# 45210   37    2        0          1        0     2971        0     0        1
#
#        month  campaign  pdays  previous  poutcome
# 45206     10         3     -1         0         0
# 45207     10         2     -1         0         0
# 45208     10         5    184         3         3
# 45209     10         4     -1         0         0
# 45210     10         2    188        11         2

# %%
target=df1['y']
target.tail(5)
# Out:
# 45206    1
# 45207    1
# 45208    1
# 45209    0
# 45210    0
# Name: y, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(non_target,target,test_size=0.2,random_state=10)

# %%
x_train.head()
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 22162   34    1        0          1        0     -255        1     0        1
# 35722   41    3        0          3        0     1428        1     1        1
# 2972    45    3        0          1        0      141        1     1        0
# 4594    38    8        0          1        0      290        1     0        0
# 37434   35    3        1          1        0     8040        1     0        1
#
#        month  campaign  pdays  previous  poutcome
# 22162      7         2     -1         0         0
# 35722      4         1     -1         0         0
# 2972       4        10     -1         0         0
# 4594       4         1     -1         0         0
# 37434      4         2     -1         0         0

# %%
x_test.head()
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 4393    55    1        2          1        0        0        1     0        0
# 4438    31    8        1          0        0     1820        1     0        0
# 11108   28    0        1          0        0     2253        1     0        0
# 35421   28    1        0          1        0     7449        1     0        1
# 2667    43    2        0          1        0       59        0     0        0
#
#        month  campaign  pdays  previous  poutcome
# 4393       4         4     -1         0         0
# 4438       4         1     -1         0         0
# 11108      5         2     -1         0         0
# 35421      4         1     -1         0         0
# 2667       4         2     -1         0         0

# %%
#Comparing difftent type of algorithms using grid search cv

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
def find_best_model_using_gridsearchcv(x,y):
    algos = {
        'RandomForest' : {
            'model': RandomForestClassifier(),
            'params': {
                'n_estimators': [10,20,30]
            }
        },
        'LogisticRegression': {
            'model':LogisticRegression(),
            'params': {
                'solver': ['lbfgs','liblinear'],
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(x,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(non_target,target)
# Out:
#                 model  best_score  \
# 0        RandomForest    0.890766
# 1  LogisticRegression    0.891098
# 2       decision_tree   -0.666492
#
#                                          best_params
# 0                               {'n_estimators': 30}
# 1                            {'solver': 'liblinear'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'best'}

# %%
#Based on the accuracy we can see that random forest and logistic regression gives us the same accuracy

# %%
from sklearn.ensemble import RandomForestClassifier
lr=RandomForestClassifier()
lr.fit(x_train,y_train)
lr.score(x_test,y_test)
# Out:
# 0.8917394669910428

# %% [markdown]
# # Generating test cases and making the predictions

# %%
lr.predict([[55,1,2,1,0,0,1,0,0,4,1,-1,0,0]])
# Out:
# array([0], dtype=int64)

# %%
lr.predict([[75,5,2,0,0,3810,1,0,1,10,1,183,1,1]])
# Out:
# array([1], dtype=int64)

# %% [markdown]
# From The above analysis we can make note of
# 1.The bank dataset contains 17 columns and 45211 rows
# 2.The dataset contains 10-object type atrributes and 7-Numerical type attribute
# 3.From the eda analysis we can make note that y of "no" attribute highest percentile than yes
# from this we can say that customer not taking loan is more than the customer taking the loan
# 4.From The coorelation analysis and heatmap we can make note that "day" and "duration"  has less correlated so we can remove those attributes
# 5.After the training on diffrent algorithms we can note that random forest and logistic regression gives us the best accuracy
# 6.So,on the random forest basis we have predicted the testing dtaset
